# %% [markdown]
# # 🎯 NicheRadar v1.5 - End-to-End Demo
#
# This notebook demonstrates the complete NicheRadar workflow:
# 1. **Data Collection** - Gather signals from multiple sources
# 2. **Scoring** - Calculate NicheScore with intelligent weighting
# 3. **Top 10 Analysis** - Identify best opportunities
# 4. **Playbook Generation** - Create execution plans
# 5. **Feedback Loop** - Track performance and learn
#
# **Author:** StillMe Framework Team
# **Version:** 1.5.0
# **Date:** 2025-09-22

# %%
# Import required modules
import asyncio
import json
import os
import sys
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Add project root to path
sys.path.append('..')

# Import NicheRadar modules
from niche_radar.collectors import collect_all_data, get_all_collectors
from niche_radar.feedback import FeedbackRecord, FeedbackTracker
from niche_radar.playbook import PlaybookGenerator
from niche_radar.scoring import NicheScorer

print("✅ NicheRadar modules imported successfully")
